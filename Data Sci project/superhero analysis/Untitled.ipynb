# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
marvel=pd.read_csv("SuperheroDataset.csv")

# %%
marvel.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1         Name                  Url  Intelligence  \
# 0           0             0      3-D Man     /3-d-man/10-226/          80.0
# 1           1             1       A-Bomb    /a-bomb/10-10060/          75.0
# 2           2             2   Abe Sapien  /abe-sapien/10-956/          95.0
# 3           3             3     Abin Sur   /abin-sur/10-1460/          80.0
# 4           4             4  Abomination   /abomination/10-1/          85.0
#
#    Strength  Speed  Durability  Power  Combat  ...         Height  \
# 0      35.0   45.0        35.0   25.0    55.0  ...  6'2 // 188 cm
# 1     100.0   20.0        80.0   25.0    65.0  ...  6'8 // 203 cm
# 2      30.0   35.0        65.0  100.0    85.0  ...  6'3 // 191 cm
# 3      90.0   55.0        65.0  100.0    65.0  ...  6'1 // 185 cm
# 4      80.0   55.0        90.0   65.0    95.0  ...  6'8 // 203 cm
#
#              Weight Eye color Hair color  \
# 0   200 lb // 90 kg     Brown       Grey
# ...

# %%
marvel=marvel[['Name','Intelligence','Strength','Speed','Durability','Power','Combat','Alignment','Total Power']]

# %%
marvel.head()
# Out:
#           Name  Intelligence  Strength  Speed  Durability  Power  Combat  \
# 0      3-D Man          80.0      35.0   45.0        35.0   25.0    55.0
# 1       A-Bomb          75.0     100.0   20.0        80.0   25.0    65.0
# 2   Abe Sapien          95.0      30.0   35.0        65.0  100.0    85.0
# 3     Abin Sur          80.0      90.0   55.0        65.0  100.0    65.0
# 4  Abomination          85.0      80.0   55.0        90.0   65.0    95.0
#
#   Alignment  Total Power
# 0      good        275.0
# 1      good        365.0
# 2      good        410.0
# 3      good        455.0
# 4       bad        470.0

# %%
marvel.shape
# Out:
# (743, 9)

# %%
marvel['Alignment'].value_counts()
# Out:
# good       499
# bad        210
# neutral     28
# -            6
# Name: Alignment, dtype: int64

# %%
marvel=(marvel[marvel['Alignment']!='-'])

# %%
marvel['Alignment'].value_counts()
# Out:
# good       499
# bad        210
# neutral     28
# Name: Alignment, dtype: int64

# %%
marvel_1=(marvel[marvel['Alignment']=='good'])

# %%
marvel_1.head()
# Out:
#           Name  Intelligence  Strength  Speed  Durability  Power  Combat  \
# 0      3-D Man          80.0      35.0   45.0        35.0   25.0    55.0
# 1       A-Bomb          75.0     100.0   20.0        80.0   25.0    65.0
# 2   Abe Sapien          95.0      30.0   35.0        65.0  100.0    85.0
# 3     Abin Sur          80.0      90.0   55.0        65.0  100.0    65.0
# 7  Adam Monroe          85.0      10.0   15.0       100.0  100.0    65.0
#
#   Alignment  Total Power
# 0      good        275.0
# 1      good        365.0
# 2      good        410.0
# 3      good        455.0
# 7      good        375.0

# %%
good=(marvel[marvel['Alignment']=='good'])

# %%
good.head()
# Out:
#           Name  Intelligence  Strength  Speed  Durability  Power  Combat  \
# 0      3-D Man          80.0      35.0   45.0        35.0   25.0    55.0
# 1       A-Bomb          75.0     100.0   20.0        80.0   25.0    65.0
# 2   Abe Sapien          95.0      30.0   35.0        65.0  100.0    85.0
# 3     Abin Sur          80.0      90.0   55.0        65.0  100.0    65.0
# 7  Adam Monroe          85.0      10.0   15.0       100.0  100.0    65.0
#
#   Alignment  Total Power
# 0      good        275.0
# 1      good        365.0
# 2      good        410.0
# 3      good        455.0
# 7      good        375.0

# %%
good.sort_values(by='Speed',ascending=False)
# Out:
#               Name  Intelligence  Strength  Speed  Durability  Power  Combat  \
# 653       Superman         100.0     100.0  100.0       100.0  100.0    85.0
# 341       Hyperion          95.0     100.0  100.0        95.0   90.0    80.0
# 397         Krypto          55.0      80.0  100.0        90.0   85.0    40.0
# 386   Kid Flash II          70.0      45.0  100.0        65.0   80.0    65.0
# 608  Silver Surfer          80.0     100.0  100.0        90.0  100.0    35.0
# ..             ...           ...       ...    ...         ...    ...     ...
# 705     Vindicator           NaN       NaN    NaN         NaN    NaN     NaN
# 709      Vision II           NaN       NaN    NaN         NaN    NaN     NaN
# 715        Warbird           NaN       NaN    NaN         NaN    NaN     NaN
# 726        Wiz Kid           NaN       NaN    NaN         NaN    NaN     NaN
# 732         Wondra           NaN       NaN    NaN         NaN    NaN     NaN
#
#     Alignment  Total Power
# ...

# %%
good.sort_values(by='Power',ascending=False).head()
# Out:
#                  Name  Intelligence  Strength  Speed  Durability  Power  \
# 741           Zatanna          95.0      10.0   25.0        30.0  100.0
# 353         Jack-Jack          35.0      35.0   70.0        80.0  100.0
# 167           Century          95.0      80.0   55.0        65.0  100.0
# 161  Captain Universe          95.0      95.0   95.0        95.0  100.0
# 160    Captain Planet          80.0      90.0   75.0        80.0  100.0
#
#      Combat Alignment  Total Power
# 741    60.0      good        320.0
# 353    10.0      good        330.0
# 167   100.0      good        495.0
# 161    85.0      good        565.0
# 160    60.0      good        485.0

# %%
good_max_power=good[good['Power']==100]

# %%
good_max_power.shape
# Out:
# (106, 9)

# %%
good_max_power
# Out:
#              Name  Intelligence  Strength  Speed  Durability  Power  Combat  \
# 2      Abe Sapien          95.0      30.0   35.0        65.0  100.0    85.0
# 3        Abin Sur          80.0      90.0   55.0        65.0  100.0    65.0
# 7     Adam Monroe          85.0      10.0   15.0       100.0  100.0    65.0
# 23          Angel          90.0      30.0   60.0        90.0  100.0    75.0
# 37        Aquaman          95.0      85.0   80.0        80.0  100.0    80.0
# ..            ...           ...       ...    ...         ...    ...     ...
# 731  Wonder Woman          95.0     100.0   80.0       100.0  100.0   100.0
# 735         X-Man          95.0      55.0   55.0        95.0  100.0    85.0
# 739          Ymir          80.0     100.0   30.0       100.0  100.0    30.0
# 740          Yoda          95.0      55.0   35.0        25.0  100.0    90.0
# 741       Zatanna          95.0      10.0   25.0        30.0  100.0    60.0
#
#     Alignment  Total Power
# 2        good        410.0
# ...

# %%
good_max_power=good.sort_values(by=['Total Power'],ascending=False)

# %%
good_max_power.head(10)
# Out:
#                   Name  Intelligence  Strength  Speed  Durability  Power  \
# 87              Binary          95.0     100.0  100.0       100.0  100.0
# 471            Monarch          95.0     100.0  100.0       100.0  100.0
# 80            Beyonder         100.0     100.0  100.0       100.0  100.0
# 653           Superman         100.0     100.0  100.0       100.0  100.0
# 652          Supergirl         100.0     100.0  100.0       100.0  100.0
# 529         Power Girl         100.0     100.0  100.0       100.0  100.0
# 434  Martian Manhunter         100.0      95.0   95.0       100.0  100.0
# 731       Wonder Woman          95.0     100.0   80.0       100.0  100.0
# 670               Thor          85.0     100.0   85.0       100.0  100.0
# 522            Phoenix         100.0     100.0   85.0       100.0  100.0
#
#      Combat Alignment  Total Power
# 87    100.0      good        595.0
# 471    95.0      good        590.0
# 80     85.0      good        585.0
# ...

# %%
plt.figure(figsize=(5,5))
plt.bar(list(good_max_power['Name'])[0:5],list(good_max_power['Total Power'])[0:5],color='g')
plt.show()

# %%
bad=marvel[marvel['Alignment']=="bad"]

# %%
bad.head()
# Out:
#              Name  Intelligence  Strength  Speed  Durability  Power  Combat  \
# 4     Abomination          85.0      80.0   55.0        90.0   65.0    95.0
# 5         Abraxas         100.0     100.0   85.0       100.0  100.0    55.0
# 6   Absorbing Man          75.0      80.0   25.0       100.0  100.0    65.0
# 12     Air-Walker          80.0      85.0  100.0        85.0  100.0    40.0
# 13           Ajax          80.0      50.0   35.0        80.0   35.0    55.0
#
#    Alignment  Total Power
# 4        bad        470.0
# 5        bad        540.0
# 6        bad        445.0
# 12       bad        490.0
# 13       bad        335.0

# %%
bad.sort_values(by=['Speed'],ascending=False).head(10)
# Out:
#                 Name  Intelligence  Strength  Speed  Durability  Power  \
# 742             Zoom          80.0      10.0  100.0        30.0  100.0
# 26            Angela          95.0     100.0  100.0       100.0  100.0
# 275      General Zod         100.0     100.0  100.0       100.0  100.0
# 12        Air-Walker          80.0      85.0  100.0        85.0  100.0
# 461  Mister Mxyzptlk         100.0      85.0  100.0       100.0  100.0
# 533   Professor Zoom         100.0      10.0  100.0        20.0   85.0
# 651   Superboy-Prime         100.0     100.0  100.0       100.0  100.0
# 195  Cyborg Superman          90.0      95.0   95.0       100.0  100.0
# 96        Black Adam          95.0     100.0   95.0       100.0  100.0
# 697           Vegeta          95.0     100.0   95.0        95.0  100.0
#
#      Combat Alignment  Total Power
# 742    30.0       bad        350.0
# 26    100.0       bad        595.0
# 275    95.0       bad        595.0
# 12     40.0       bad        490.0
# ...

# %%
bad.sort_values(by=['Intelligence'],ascending=False).head(10)
# Out:
#                 Name  Intelligence  Strength  Speed  Durability  Power  \
# 679         Tinkerer         100.0      10.0   25.0        15.0   10.0
# 292  Granny Goodness         100.0     100.0   90.0       100.0   95.0
# 137         Brainiac         100.0      95.0   65.0        90.0   60.0
# 432         Mandarin         100.0      30.0   25.0        30.0  100.0
# 511       Ozymandias         100.0      20.0   35.0        20.0   50.0
# 651   Superboy-Prime         100.0     100.0  100.0       100.0  100.0
# 5            Abraxas         100.0     100.0   85.0       100.0  100.0
# 646      Steppenwolf         100.0     100.0   85.0       100.0  100.0
# 564          Riddler         100.0      10.0   15.0        15.0   10.0
# 275      General Zod         100.0     100.0  100.0       100.0  100.0
#
#      Combat Alignment  Total Power
# 679    15.0       bad        175.0
# 292   100.0       bad        585.0
# 137    75.0       bad        485.0
# 432    95.0       bad        380.0
# ...

# %%
bad.sort_values(by=['Total Power'],ascending=False).head(15)
# Out:
#                 Name  Intelligence  Strength  Speed  Durability  Power  \
# 275      General Zod         100.0     100.0  100.0       100.0  100.0
# 26            Angela          95.0     100.0  100.0       100.0  100.0
# 292  Granny Goodness         100.0     100.0   90.0       100.0   95.0
# 646      Steppenwolf         100.0     100.0   85.0       100.0  100.0
# 651   Superboy-Prime         100.0     100.0  100.0       100.0  100.0
# 697           Vegeta          95.0     100.0   95.0        95.0  100.0
# 204         Darkseid          95.0     100.0   85.0       100.0  100.0
# 82         Big Barda          95.0     100.0   80.0       100.0  100.0
# 19             Amazo          85.0     100.0   85.0       100.0  100.0
# 686           Trigon          95.0     100.0   85.0       100.0  100.0
# 195  Cyborg Superman          90.0      95.0   95.0       100.0  100.0
# 231         Dormammu          95.0      95.0   85.0       100.0  100.0
# ...

# %%
plt.figure(figsize=(5,5))
plt.hist(good['Speed'])
plt.title('distribution of speed')
plt.xlabel('Speed')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.hist(bad['Combat'])
plt.show()
